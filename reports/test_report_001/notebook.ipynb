# %% [markdown]
# # DS Copilot Analysis
# **Dataset:** sample.csv

# %% [markdown]
# **Instructions:** Place your dataset file in the same directory as this notebook before running.
# Expected file: `sample.csv`

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('sample.csv')
df.columns = [col.strip().lower() for col in df.columns]
print(df.shape)
df.head()
# Out:
# (7, 4)
#    age  salary     dept  experience
# 0   25   50000       HR           2
# 1   30   60000       IT           5
# 2   35   70000  Finance           8
# 3   40   80000       IT          12
# 4   45   90000       HR          15

# %% [markdown]
# ## Exploratory Data Analysis

# %%
print('Shape:', df.shape)
print('\nDtypes:')
print(df.dtypes)
print('\nDescribe:')
df.describe(include='all')
# Out:
# Shape: (7, 4)
#
# Dtypes:
# age           int64
# salary        int64
# dept            str
# experience    int64
# dtype: object
#
# Describe:
#               age        salary dept  experience
# count    7.000000      7.000000    7    7.000000
# unique        NaN           NaN    3         NaN
# top           NaN           NaN   IT         NaN
# freq          NaN           NaN    3         NaN
# mean    33.714286  67142.857143  NaN    7.428571
# std      6.969321  14099.983114  NaN    4.720775
# min     25.000000  50000.000000  NaN    2.000000
# 25%     29.000000  57500.000000  NaN    4.000000
# 50%     33.000000  65000.000000  NaN    7.000000
# 75%     37.500000  75000.000000  NaN   10.000000
# max     45.000000  90000.000000  NaN   15.000000

# %% [markdown]
# ### Missing Values

# %%
missing = df.isnull().sum()
missing_pct = (missing / len(df)) * 100
pd.DataFrame({'count': missing, 'percentage': missing_pct})[missing > 0].sort_values('percentage', ascending=False)
# Out:
# Empty DataFrame
# Columns: [count, percentage]
# Index: []

# %% [markdown]
# ### Correlation Analysis

# %%
corr = df.select_dtypes(include='number').corr()
px.imshow(corr, color_continuous_scale='RdBu_r', zmin=-1, zmax=1, title='Correlation Heatmap')

# %% [markdown]
# ### Outlier Analysis

# %%
for col in df.select_dtypes(include='number').columns:
    px.box(df, y=col, title=f'Box Plot of {col}').show()

# %% [markdown]
# ## Insights
# Age and  salary are strongly correlated.
